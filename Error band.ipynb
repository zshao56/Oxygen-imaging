# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline


# 加载数据
file_path = r"F:\OneDrive - UW-Madison\python\figure&summary\error band data\sample colors.txt"
data = pd.read_csv(file_path, delimiter="\t", header=None)

# 提取数据
x = data.iloc[:, 0]
y1 = data.iloc[:, 1]
y1_error = data.iloc[:, 2]
y2 = data.iloc[:, 3]
y2_error = data.iloc[:, 4]

plt.figure(figsize=(7, 6))


x_smooth = np.linspace(x.min(), x.max(), 300)
spl = make_interp_spline(x, y1)
y1_smooth = spl(x_smooth)
spl = make_interp_spline(x, y1_error)
y1_error_smooth = spl(x_smooth)
plt.plot(x_smooth, y1_smooth, color='blue', linestyle='--')
plt.fill_between(x_smooth, y1_smooth - y1_error_smooth, y1_smooth + y1_error_smooth, alpha=0.2)  # 绘制 y1 误差带


spl = make_interp_spline(x, y2)
y2_smooth = spl(x_smooth)
spl = make_interp_spline(x, y2_error)
y2_error_smooth = spl(x_smooth)
plt.plot(x_smooth, y2_smooth, color='red', linestyle='--')
plt.fill_between(x_smooth, y2_smooth - y2_error_smooth, y2_smooth + y2_error_smooth, alpha=0.2)  # 绘制 y2 误差带


plt.xlim(1, 4)
plt.ylim(0, 1)
plt.xticks(np.arange(1, 5, step=1))
plt.yticks(np.arange(0, 1.2, step=0.2))

# 添加标题和标签

plt.xlabel('X')
plt.ylabel('Y')
plt.legend()

plt.savefig(r'F:\OneDrive - UW-Madison\python\figure&summary\pdf\sample_colors.pdf')
# 显示图形
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
